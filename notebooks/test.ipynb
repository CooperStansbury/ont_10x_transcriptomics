# %%
import anndata as an
import scanpy as sc
import pandas as pd
import numpy as np
import os
from scipy.sparse import csr_matrix
from scipy.sparse import issparse
import gget
import pyranges as pr

import seaborn as sns
import matplotlib.pyplot as plt

sc.settings.verbosity = 3

# %%
fpath = "/scratch/indikar_root/indikar1/shared_data/epi2me_pipeline_run/outputs/full_reads_run_mar_19/32f7539deda847c0a5dc4405f98ebd86/32f7539deda847c0a5dc4405f98ebd86.transcriptome.gff.gz"

gdf = pr.read_gff(fpath)
gdf.head()
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# |   Chromosome | Source     | Feature      |     Start |       End | +15   |
# |   (category) | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# |            1 | StringTie  | transcript   |     16958 |     17607 | ...   |
# |            1 | StringTie  | exon         |     16958 |     17053 | ...   |
# |            1 | StringTie  | exon         |     17230 |     17607 | ...   |
# |            1 | StringTie  | transcript   |     34893 |     35511 | ...   |
# |            1 | StringTie  | exon         |     34893 |     35511 | ...   |
# |            1 | StringTie  | transcript   |     39610 |     39935 | ...   |
# |            1 | StringTie  | exon         |     39610 |     39935 | ...   |
# |            1 | StringTie  | transcript   |    134774 |    136110 | ...   |
# ...

# %%
df = gdf.df
df = df[df['Feature'] == 'transcript']
df = df[df['gene_name'].notna()]
print(f"{df.shape=}")
df.head()
# Out:
# df.shape=(250320, 20)
#   Chromosome     Source     Feature   Start     End Score Strand Frame  \
# 0          1  StringTie  transcript   16958   17607     .      +     .
# 3          1  StringTie  transcript   34893   35511     .      +     .
# 5          1  StringTie  transcript   39610   39935     .      +     .
# 7          1  StringTie  transcript  134774  136110     .      +     .
# 9          1  StringTie  transcript  137906  140458     .      +     .
#
#       transcript_id         gene_id         xloc class_code tss_id  \
# 0  1.stringtie.79.1  1.stringtie.79  XLOC_000001          s   TSS1
# 3  1.stringtie.81.1  1.stringtie.81  XLOC_000002          x   TSS2
# 5  1.stringtie.82.1  1.stringtie.82  XLOC_000003          u   TSS3
# 7  1.stringtie.95.1  1.stringtie.95  XLOC_000004          o   TSS4
# 9  1.stringtie.97.1  1.stringtie.97  XLOC_000005          s   TSS5
#
#   exon_number          cmp_ref     cmp_ref_gene contained_in gene_name  \
# ...

# %%
df = df[df['Feature'] == 'transcript']
